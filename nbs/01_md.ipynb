# %% [markdown]
# # Postprocessing
#
# > Postprocessing markdown files including fixing heading hierarchy and adding image descriptions

# %% [markdown]
# Don't you think that's "postprocessing" is a bit long for a module name?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You're right! "postprocessing" can feel a bit verbose. What kind of module is this, and what does it do? That might help me suggest some shorter alternatives.
#
# For example, if it's mainly about fixing markdown files, you could consider names like:
# - `mdfix`
# - `mdclean`
# - `postproc`
# - `fixmd`
#
# What feels right to you, and what's the main purpose of the module?
